# %%
from bs4 import *
import requests
import re
import pandas as pd

# %%
url = "https://beacon.schneidercorp.com/Application.aspx?AppID=165&LayerID=2145&PageTypeID=4&PageID=1108&Q=1194192114&KeyValue=0201100105"

# %%
table = pd.read_html(url)

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="local,government,courthouse,beacon,real estate,gis,maps" name="keywords"/><meta content="Online access to maps, real estate data, tax information, and appraisal data." name="description"/><meta content="no" http-equiv="imagetoolbar"/><meta content=" Beacon Home " name="application-name"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="Images/Logos/Win8TileLogo.png" name="msapplication-TileImage"/><meta content="telephone=no" name="format-detection"/>
# <script src="/cdn/60d45d90/js/webfontloader.js"></script>
# <script>
#
#     WebFont.load({
#         custom: {
#             families: ['fontello-icons', 'Glyphicons Halflings'], //
#             testStrings: {
#                 'fontello-icons': '\ue800\ue801\ue802\ue803\ue833\ue83c',
#                 'Glyphicons Halflings': '\ue003\ue011\ue053\u2212\u002b'
#             }
#         },
#         google: {
#             families: ['Lato:400,700,400italic,700italic']
#         },
#         timeout: 30000
#     });
# </script>
# <link href="/cdn/60d45d90/css/bootstrap.css" rel="stylesheet"/>
# <link href="/cdn/60d45d90/css/core.min.css" rel="stylesheet"/>
# <link href="/cdn/60d45d90/css/sprite.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
# <script src="/cdn/60d45d90/js/html5shiv.min.js"></script>
# <script src="/cdn/60d45d90/js/respond.min.js"></script>
# <![endif]-->
# <script src="/cdn/60d45d90/js/libs.min.js"></script>
# <script src="/cdn/60d45d90/js/core.min.js"></script>
# <script src="/cdn/60d45d90/js/core-templates.min.js"></script>
# <script>
#         Beacon.PageInitialization();
#     </script>
# <script>window.ga = window.ga || function () { (ga.q = ga.q || []).push(arguments) };ga.l = +new Date;ga('create', 'UA-1185949-6', 'auto');ga('send', 'pageview',"/StoryCountyIA/Parcels/Report/Report?KeyValue=0201100105");</script><script async="" src="https://www.google-analytics.com/analytics.js"></script>
# <title>
# 	Beacon - Story County, IA / City of Ames - Report: 0201100105
# </title></head>
# <body class="body-background" id="appBody">
# <form action="./Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=1194192114&amp;KeyValue=0201100105" id="Form1" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="ejOKFdYK9JC0tCuYLnjziLUJ3/z2jVNVdJaJAbGnDQGSXLhVbE9iq5wETeRx8QbUBx35/8gwxcynehil/2QxYnpqtk8DD5wPY/eajj5bDwP6Jplbtp6ifcaUHAKzL4A8i1e+9zfegr3rt7rQ+W3HuN99XeCQ7X6rv0n9DX5tO6GypiLPWtQwR8P2J/mq27NAXR+jVAHBgBNm7sVwoFsqpdBEFlCdRSFPieWK3gT1NSXrc/BM"/>
# <script type="text/javascript">
# //<![CDATA[
# var mapConfig = {"AppId":165,"LayerId":2145,"PageId":1108,"PageTypeId":4,"KeyValue":"0201100105","QPS":"x52W-TD5qHwDv02ye60KfumJ0Hr-jcr9ziAoZXUr3mdrdY456c8IU6wQ1eBWHSv-D65cjrEBFvUvgloFcK1yKcCn_KV-2ipBnJ7I-3V6Spcv6bLS9lz7l0fJN5eHPtQdiUrVp3ZuZGiseUg1u5BG0dDb4B1mJOcmtvEe6c6AmYkU3f7pH6nAmr0G_sVZF-fZ5TZYB27uhocekFChq6mxIAw49Lj8jX2H3XgEM1JChZHvHJEEHSL5krbu7tni6ckqAMqJ4r-LZ_JyG0phXX1e_ximHVmSjylGNGbHlf0tKh01","Tabs":[{"Name":"Map","PageId":1110,"PageTypeId":1,"Icon":"WorldClick","nk":false,"nr":false,"p":true,"NavigateUrl":null},{"Name":"Search","PageId":1104,"PageTypeId":2,"Icon":"Search","nk":false,"nr":false,"p":true,"NavigateUrl":null},{"Name":"Ames Comp","PageId":1105,"PageTypeId":2,"Icon":"Search","nk":false,"nr":false,"p":true,"NavigateUrl":null},{"Name":"Story Comp","PageId":1279,"PageTypeId":2,"Icon":"Search","nk":false,"nr":false,"p":true,"NavigateUrl":null},{"Name":"Results","PageId":1106,"PageTypeId":3,"Icon":"SearchDocument","nk":false,"nr":true,"p":true,"NavigateUrl":null},{"Name":"Comp Results","PageId":1107,"PageTypeId":3,"Icon":"SearchDocument","nk":false,"nr":true,"p":true,"NavigateUrl":null},{"Name":"Report","PageId":1108,"PageTypeId":4,"Icon":"Report","nk":true,"nr":false,"p":true,"NavigateUrl":null},{"Name":"Soil Report","PageId":1137,"PageTypeId":4,"Icon":"Report","nk":true,"nr":false,"p":true,"NavigateUrl":null},{"Name":"Pictometry Imagery","PageId":3362,"PageTypeId":4,"Icon":"Report","nk":true,"nr":false,"p":true,"NavigateUrl":null}],"ResultCount":1,"Serial":637299882070903450,"Links":[{"Name":"Property Search","Text":"Search public real estate records for assessment, tax, sales, ownership and other property information","Url":"Application.aspx?AppID=165\u0026LayerID=2145\u0026PageTypeID=2\u0026PageID=1104"},{"Name":"View Map","Text":"Interactive map to view property locations and layers of other community information","Url":"Application.aspx?AppID=165\u0026LayerID=2145\u0026PageTypeID=1\u0026PageID=1110"}],"DefaultReportUrl":"/Application.aspx?AppID=165\u0026LayerID=2145\u0026PageTypeID=4\u0026PageID=1108\u0026Q=219522459\u0026KeyValue={0}","IsMapPage":false,"CurrentExtent":null,"MaxExtent":null,"SRID":0,"Units":null,"BeaconLayers":null,"AgsTileLayers":null,"KeySymbology":null,"SelectionSymbology":null,"BufferSymbology":null,"HoverSymbology":null,"Permissions":null,"Search":{"Name":false,"Address":true,"ParcelId":true},"Projections":null,"LayerView":[{"GroupId":0,"GroupName":"Parcel Mapping","Layers":[{"LayerId":2264,"ServerId":17501,"LayerName":"Parcel Numbers","Query":false,"QuickZoom":false,"VisibilityGroup":null,"Visible":false,"DefaultVisibility":false,"Locked":false,"ScaleMin":0.000868055555556,"ScaleMax":4.34027777778,"HasMap":true,"DefaultLayer":false,"LayerChangeUrl":null},{"LayerId":2145,"ServerId":17501,"LayerName":"Parcels","Query":true,"QuickZoom":false,"VisibilityGroup":null,"Visible":true,"DefaultVisibility":true,"Locked":false,"ScaleMin":0.000868055555556,"ScaleMax":26.0416666667,"HasMap":true,"DefaultLayer":true,"LayerChangeUrl":null},{"LayerId":2263,"ServerId":17501,"LayerName":"Lots","Query":true,"QuickZoom":false,"VisibilityGroup":null,"Visible":true,"DefaultVisibility":true,"Locked":false,"ScaleMin":0.000868055555556,"ScaleMax":8.68055555556,"HasMap":true,"DefaultLayer":false,"LayerChangeUrl":null},{"LayerId":2265,"ServerId":17501,"LayerName":"Right of Way","Query":true,"QuickZoom":false,"VisibilityGroup":null,"Visible":false,"DefaultVisibility":false,"Locked":false,"ScaleMin":0.000868055555556,"ScaleMax":21.7013888889,"HasMap":true,"DefaultLayer":false,"LayerChangeUrl":null}]},{"GroupId":1,"GroupName":"Zoning","Layers":[{"LayerId":2274,"ServerId":446,"LayerName":"Zoning Districts (Ames)","Query":true,"QuickZoom":false,"VisibilityGroup":null,"Visible":false,"DefaultVisibility":false,"Locked":false,"ScaleMin":0,"ScaleMax":0,"HasMap":true,"DefaultLayer":false,"LayerChangeUrl":null},{"LayerId":2266,"ServerId":446,"LayerName":"Zoning Overlays (Ames)","Query":true,"QuickZoom":false,"Visibility ...
# </script>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="569DB96F"/>
# <div class="load-bar" id="main_prog_ind" style="display: none">
# <div class="bar"></div>
# <div class="bar"></div>
# <div class="bar"></div>
# </div>
# <div class="sr-only" id="prog_status_update" role="status"></div>
# <div class="skip-to-content">
# <a href="#maincontent">Skip to main content</a>
# </div>
# <header class="beacon-header-container" role="banner">
# <div class="container">
# <div class="row visible-desktop beacon-header-large">
# <div class="leftside">
# <a href="/" id="ctlHeader_lnkHomepage" title="Homepage">
# <img alt="Beacon Logo" aria-label="Return to homepage" class="img" id="ctlHeader_imgLogo" src="/Images/DefaultTheme/logo.png"/></a>
# <h1 class="header-title" id="ctlHeader_hAppName">Story County, IA / City of Ames</h1>
# </div>
# <div class="rightside">
# <div class="myacct NoPrint">
# <div id="ctlHeader_liLoggedOut">
# <a href="/Account/Login?ReturnUrl=%2fApplication.aspx%3fAppID%3d165%26LayerID%3d2145%26PageTypeID%3d4%26PageID%3d1108%26Q%3d1194192114%26KeyValue%3d0201100105" id="ctlHeader_lnkLogIn"><span class="icon icon-user"></span>Log In</a>
# </div>
# </div>
# <div class="logo NoPrint" id="ctlHeader_headerLogoIcon">
# <a class="navbar-link" href="http://schneidergis.com" tabindex="-1" title="Schneider Geospatial">
# <img alt="Schneider Geospatial Logo" class="logo" height="36" src="/Images/Logos/sg-stacked.png"/>
# </a>
# </div>
# <div class="search NoPrint" id="ctlHeader_divSearch" style="z-index:9999">
# <div class="has-feedback">
# <input aria-label="Global search" class="tt-upm-global-search form-control" id="topSearchControl" placeholder="search..." title="search" type="search"/>
# <span aria-hidden="true" class="glyphicon glyphicon-search form-control-feedback" style="z-index:2"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="row hidden-desktop beacon-header-small">
# <div class="leftside">
# <a href="/" id="ctlHeader_lnkHomepageSmall" title="Beacon Homepage">
# <img alt="Beacon Logo" aria-label="Return to homepage" class="" id="ctlHeader_imgLogoSmall" src="/Images/DefaultTheme/logo-small.png"/></a>
# <h1 class="header-title" id="ctlHeader_hAppName2">Story County, IA / City of Ames</h1>
# </div>
# </div>
# </div>
# </header>
# <script>
#     (function () {
#
#         var smallScreenHeader = $(".beacon-header-small");
#         if (smallScreenHeader && smallScreenHeader.is(":visible")) {
#             var title = $("#ctlHeader_hAppName2");
#             if (title && title.text()) {
#                 if (title.text().length > 23) {
#                     smallScreenHeader.removeClass("beacon-header-small").addClass("beacon-header-small-long-title");
#                 }
#             }
#         }
#
#
#     }) ();
# </script>
# <div id="tabAffix">
# <div class="beacon-navbar beacon-navbar-inverse" data-offset-top="60" role="navigation">
# <div class="container">
# <div aria-label="Page navigation" class="row" id="tabRow" role="tablist" style="position: absolute;">
# <div class="nav beacon-navbar-nav" id="Tabs_elTocDropdown">
# <div class="dropdown simple-layer-dropdown-li" role="menu" style="display:none;">
# <a aria-expanded="false" aria-haspopup="true" class="visible-desktop" data-toggle="dropdown" href="#" role="button">
# <span class="icon icon-layers"></span>
#                             Layers <b class="caret"></b>
# </a>
# <a aria-expanded="false" aria-haspopup="true" class="hidden-desktop" data-toggle="dropdown" href="#" role="button">
# <span class="icon icon-layers"></span><span class="sr-only">Layers</span>
# <b class="caret"></b>
# </a>
# <ul class="dropdown-menu slim-scrollbar" id="ddlSimpleLayerList" style="max-height:600px; overflow-y:scroll;">
# </ul>
# </div>
# </div>
# <ul class="nav beacon-navbar-nav tab-template-area">
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script>
#     Beacon.Tabs.initialize(false);
# </script>
# <div class="container page-container">
# <div class="row">
# <div class="col-md-10 page-center-pane">
# <div class="headerNotifications alert alert-warning alert-dismissable" style="display: none;">
# <button aria-hidden="true" class="close" data-dismiss="alert" type="button">×</button>
# <span class="glyphicon glyphicon-warning-sign"></span><b>WARNING!</b>
# <span class="headerNotification1">Warning!  This is a message!</span>
# </div>
# <div class="main-toolbar">
# <div class="dropdown" id="shareDropDown" style="display:inline-block">
# <button aria-expanded="false" aria-haspopup="true" class="glyphicon glyphicon-share" data-toggle="dropdown" id="shareIcons" title="Share this page"></button>
# <ul aria-labelledby="shareIcons" class="dropdown-menu" id="ToolBar1_shareOptions" role="menu">
# <li class="print-layout-1" id="ToolBar1_liFacebook"><a href="#" id="aFacebook" role="menuitem" target="_blank"><img alt="Share on Facebook - Opens in a new tab" src="/Images/facebook_32_black.png"/>Share on Facebook</a></li>
# <li class="print-layout-2" id="ToolBar1_liTwitter"><a href="#" id="aTwitter" role="menuitem" target="_blank"><img alt="Share on Twitter - Opens in a new tab" src="/Images/twitter_32_black.png"/>Share on Twitter</a></li>
# <li class="print-layout-3" id="ToolBar1_liLinkedIn"><a href="#" id="aLinkedIn" role="menuitem" target="_blank"><img alt="Share on LinkedIn - Opens in a new tab" src="/Images/linkedin_32_black.png"/>Share on LinkedIn</a></li>
# </ul>
# </div>
# <a href="#" id="btnToolbarBrowserPrint" title="Print"><span class="glyphicon glyphicon-print"></span><span class="sr-only">Print</span></a>
# <div class="dropdown" id="printSettingsDropdown" style="display:inline-block">
# <button aria-expanded="false" aria-haspopup="true" class="" data-toggle="dropdown" id="dropdownMenuPrintSettings" title="Set print layout">
# <span class="glyphicon glyphicon-cog"></span>
# </button>
# <ul aria-labelledby="dropdownMenuPrintSettings" class="dropdown-menu" id="ToolBar1_imageOptions" role="menu">
# <li class="print-layout-1" id="ToolBar1_largeImages"><a href="#" onclick="Beacon.PrintDialog.setPrintLayout(1)" role="menuitemradio"><span class="glyphicon glyphicon-ok"></span>Large images</a></li>
# <li class="print-layout-2" id="ToolBar1_smallImages"><a href="#" onclick="Beacon.PrintDialog.setPrintLayout(2)" role="menuitemradio"><span class="glyphicon glyphicon-ok"></span>Small images</a></li>
# <li class="print-layout-3" id="ToolBar1_noImages"><a href="#" onclick="Beacon.PrintDialog.setPrintLayout(3)" role="menuitemradio"><span class="glyphicon glyphicon-ok"></span>No images</a></li>
# </ul>
# </div>
# <a href="mailto:?body=https%3a%2f%2fbeacon.schneidercorp.com%2fApplication.aspx%3fAppID%3d165%26LayerID%3d2145%26PageTypeID%3d4%26PageID%3d1108%26KeyValue%3d0201100105" id="ToolBar1_imgEmailLink" onclick="DisablePleaseWaitDialog();" title="Email Link"><span class="glyphicon glyphicon-envelope"></span><span class="sr-only">Email Link</span></a>
# <a aria-label="View previous record" href="javascript:__doPostBack('ToolBar1$btnPrevRecord','')" id="ToolBar1_btnPrevRecord" title="View previous record"><span class="glyphicon glyphicon-arrow-left"></span></a>
# <a aria-label="View next record" href="javascript:__doPostBack('ToolBar1$btnNextRecord','')" id="ToolBar1_btnNextRecord" title="View next record"><span class="glyphicon glyphicon-arrow-right"></span></a>
# <span id="wexfordActionDiv" style="display: none;">
# <i class="sprite RippleLogo" title=""></i>
#         ripple:
#         <select aria-label="View in" id="ddlWexfordAction" onchange="Wexford_Action();">
# <option selected="selected" value="-1">View in:</option>
# </select>
# </span>
# <script>
#         $(function () { Wexford_Init(); });
#
#         var currentHref = encodeURIComponent(window.location.href);
#         $("#aFacebook").attr("href", "https://www.facebook.com/sharer/sharer.php?u=" + currentHref);
#         $("#aTwitter").attr("href", "http://twitter.com/share?url=" + currentHref);
#         $("#aLinkedIn").attr("href", "https://www.linkedin.com/shareArticle?mini=true&url=" + currentHref);
#
#     </script>
# </div>
# <main id="maincontent">
# <section id="ctlBodyPane_ctl00_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl00_divHeader" moduleid="7124">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=990050387&amp;KeyValue=0201100105" id="ctlBodyPane_ctl00_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl00_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl00_lblName" role="heading">Summary</div>
# </a>
# </header>
# <div class="module-content">
# <div class="primary-photo-rs royalSlider rsDefault NoPrint" id="ctlBodyPane_ctl00_ctl01_PhotoCarousel_divPhoto"></div>
# <img alt="Property photo" class="primary-photo-rs-print NoScreen" id="ctlBodyPane_ctl00_ctl01_PhotoCarousel_imgPhoto" onerror="Beacon.LazyLoader.swapImageOnFailure" photourls="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/0?sv=2015-07-08&amp;sr=b&amp;sig=kjNhw28WrklaDtjrEvOjoNBSd2qJR16U4ET75DqR2Ho%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" src="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/0?sv=2015-07-08&amp;sr=b&amp;sig=kjNhw28WrklaDtjrEvOjoNBSd2qJR16U4ET75DqR2Ho%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline"/>
# <div>
# <strong> <span id="ctlBodyPane_ctl00_ctl01_lblAssessor"><font size="4">Story County Assessor</font></span><br/>
# <br/>
# </strong>
# </div>
# <div class="block-row">
# <div class="block-group two-column-blocks">
# <table class="tabular-data-two-column">
# <tr>
# <td style="width: 152" valign="top">
# <strong><strong><strong>Sec-Twp-Rng </strong></strong></strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblSecTwpRng" style="display:inline-block;">01-85-23</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Brief Tax Description</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblLegalDescription" style="display:inline-block;">SECTION:01  TOWNSHIP:85  RANGE:23 NW NW PARCEL"A"CFN 13-46</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Primary Class</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblPrimClass" style="display:inline-block;">Residential</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Primary Zoning</strong>
# </td>
# <td>
# <a href="http://www.storycountyiowa.gov/DocumentCenter/View/4465" id="ctlBodyPane_ctl00_ctl01_hlkPrimZoning" target="_blank" title="Opens in a new tab">A-1, Agricultural</a>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Secondary Zoning</strong></td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblSecZoning">N/A</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Zoning Overlay</strong></td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblZoneOverlay">N/A</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Secondary Zoning Overlay</strong></td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblSecZoneOverlay">N/A</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Gross Acres</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblGrossAcres" style="display:inline-block;">12.21</span>
# <span id="ctlBodyPane_ctl00_ctl01_Label3">N/A</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Net Acres</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblNetAcres" style="display:inline-block;">10.94</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Last Transfer
#                         <br/>
#                         Recording Date</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblLastRecDate" style="display:inline-block;">7/1/2004</span>
# </td>
# </tr>
# <tr>
# <td valign="top" width="152">
# <strong>Deed Book/Page
#                         <br/>
#                         (Instr. Date)</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblDeedBookPage" style="display:inline-block;">2004-08964 (6/30/2004)</span>
# </td>
# </tr>
# <tr>
# <td valign="top" width="152">
# <strong>Contract Book/Page
#                         <br/>
#                         (Instr. Date)</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblContractBookPage" style="display:inline-block;">N/A</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>Taxing District</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblTaxingDistrict" style="display:inline-block;">HOWARD TWP/ROLAND-STORY SCH</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>School District</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblSchoolDistrict" style="display:inline-block;">ROLAND-STORY COMMUNITY SCHOOL</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152" valign="top">
# <strong>TIF/UR District</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblTIFDistrict" style="display:inline-block;">N/A</span>
# </td>
# </tr>
# <tr>
# <td style="width: 152;" valign="top">
# <strong>Drainage District</strong></td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblDrainDistrict" style="display:inline-block;">N/A</span></td>
# </tr>
# </table>
# </div>
# <div class="block-group two-column-blocks">
# <div class="block-row">
# <table class="tabular-data-two-column">
# <tr>
# <td>
# <strong>Property ID</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblParcelID" style="display:inline-block;">02-01-100-105</span>
# </td>
# </tr>
# <tr>
# <td>
# <strong>
# <span id="ctlBodyPane_ctl00_ctl01_lblMapIDLabel">Map ID</span></strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblMapID">02-01-100-105</span>
# </td>
# </tr>
# <tr>
# <td>
# <strong>Property Address</strong>
# </td>
# <td>
# <span id="ctlBodyPane_ctl00_ctl01_lblPropertyAddress" style="display:inline-block;">61158 100TH ST<br/>RADCLIFFE</span>
# </td>
# </tr>
# </table>
# </div>
# <div class="block-row">
# <a id="ctlBodyPane_ctl00_ctl01_hlkName" target="_blank" title="Opens in a new tab"></a>
# </div>
# </div>
# </div>
# <div class="block-row">
# <a id="ctlBodyPane_ctl00_ctl01_hlkEncroachmentZBA" target="_blank" title="Opens in a new tab"></a>
# </div>
# </div>
# </section>
# <section id="ctlBodyPane_ctl01_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl01_divHeader" moduleid="7125">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=1760578315&amp;KeyValue=0201100105" id="ctlBodyPane_ctl01_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl01_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl01_lblName" role="heading">Owner</div>
# </a>
# </header>
# <div class="module-content">
# <div class="block-row">
# <div class="three-column-blocks">
# <table cellspacing="0" id="ctlBodyPane_ctl01_ctl01_lstDeed" role="presentation">
# <tr>
# <td><b>
#                 Deed Holder
#             </b></td>
# </tr><tr>
# <td>
# <span id="ctlBodyPane_ctl01_ctl01_lstDeed_ctl01_lblDeedName_lblSearch">RISDAL, AARON M &amp; DAWN M</span>
# <span id="ctlBodyPane_ctl01_ctl01_lstDeed_ctl01_lblAttention"></span>
# <span id="ctlBodyPane_ctl01_ctl01_lstDeed_ctl01_lblAddress1"><br/>61158 100TH ST</span>
# <span id="ctlBodyPane_ctl01_ctl01_lstDeed_ctl01_lblAddress3"><br/>RADCLIFFE IA 50230-8724</span>
# </td>
# </tr>
# </table>
# </div>
# <div class="three-column-blocks">
# <table cellspacing="0" id="ctlBodyPane_ctl01_ctl01_lstContract" role="presentation">
# <tr>
# <td><b>
#                 Contract Holder
#             </b></td>
# </tr>
# </table>
# </div>
# <div class="three-column-blocks">
# <table cellspacing="0" id="ctlBodyPane_ctl01_ctl01_lstMailing" role="presentation">
# <tr>
# <td><b>
#                 Mailing Address
#             </b></td>
# </tr><tr>
# <td>
# <span id="ctlBodyPane_ctl01_ctl01_lstMailing_ctl01_lblMailing">RISDAL, AARON M &amp; DAWN M<br>61158 100TH ST<br>RADCLIFFE IA 50230-8724</br></br></span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <center><a href="http://www.storycountyiowa.gov/DocumentCenter/Home/View/267" target="_blank"><b>Change mailing address</b></a><br/><a href="https://tax.iowa.gov/sites/default/files/idr/forms1/Transfer%20Change%20Homestead%20Military%2059458_0.pdf" target="_blank"><b>Transfer Homestead or Military</b></a></center>
# </div>
# </section>
# <section id="ctlBodyPane_ctl02_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl02_divHeader" moduleid="34488">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=32250705&amp;KeyValue=0201100105" id="ctlBodyPane_ctl02_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl02_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl02_lblName" role="heading">Property Record Card</div>
# </a>
# </header>
# <div class="module-content">
# <div id="ctlBodyPane_ctl02_ctl01_pnlMain">
# <a href="https://venturi.blob.core.windows.net/fd-3256/0201100105/0?sv=2015-07-08&amp;sr=b&amp;sig=dEYHnjE5AgONHDUgBhBuudaZzXnaL7Xdeevk7BPPSuE%3D&amp;se=2020-07-17T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline%3B%20filename%3D%220201100105_0.pdf%22" id="ctlBodyPane_ctl02_ctl01_prtrFiles_ctl00_hlkName" target="_blank" title="Opens Click to View/Print 2020 Property Record Card in a new tab">Click to View/Print 2020 Property Record Card</a><br>
# </br></div>
# <div id="ctlBodyPane_ctl02_ctl01_pnlButtonMain">
# </div>
# </div>
# </section>
# <section id="ctlBodyPane_ctl04_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl04_divHeader" moduleid="3235">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=1828362461&amp;KeyValue=0201100105" id="ctlBodyPane_ctl04_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl04_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl04_lblName" role="heading">Land</div>
# </a>
# </header>
# <div class="module-content">
# <div id="ctlBodyPane_ctl04_ctl01_pnlSumRegular">
# <table class="tabular-data-two-column">
# <tr>
# <td>Lot Area
#             </td>
# <td>
# <span id="ctlBodyPane_ctl04_ctl01_lblSumAcres">10.94</span> Acres
#                 <span id="ctlBodyPane_ctl04_ctl01_lblSumAreaSemiColon">; </span>
# <span id="ctlBodyPane_ctl04_ctl01_lblSumArea">476,546</span>
# <span id="ctlBodyPane_ctl04_ctl01_lblSF"> SF</span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </section>
# <section id="ctlBodyPane_ctl05_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl05_divHeader" moduleid="3236">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=1828362461&amp;KeyValue=0201100105" id="ctlBodyPane_ctl05_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl05_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl05_lblName" role="heading">Residential Dwellings</div>
# </a>
# </header>
# <div class="module-content">
# <table class="editorHiddenForNormalUsers tabular-data-two-column">
# <tr>
# <td>
# <b>Administrative</b>
# </td>
# <td></td>
# </tr>
# <tr>
# <td>
# <b>Purpose of visit</b>
# </td>
# <td>
# <span editgroup="Res" editkey="Purpose"></span>
# </td>
# </tr>
# <tr>
# <td>
# <b>Inspection Status</b>
# </td>
# <td>
# <span editgroup="Res" editkey="InspectionStatus"></span>
# </td>
# </tr>
# <tr>
# <td>
# <b>Tag Left</b>
# </td>
# <td>
# <span editgroup="Res" editkey="TagLeft"></span>
# </td>
# </tr>
# <tr>
# <td>
# <b>Appointment Requested</b>
# </td>
# <td>
# <span editgroup="Res" editkey="ApptRequested"></span>
# </td>
# </tr>
# <tr>
# <td>
# <b>Memo</b>
# </td>
# <td>
# <span editgroup="Res" editkey="Notes"></span>
# </td>
# </tr>
# </table>
# <hr class="editorHiddenForNormalUsers"/>
# <table cellspacing="0" id="ctlBodyPane_ctl05_ctl01_lstResidential" role="presentation">
# <tr>
# <td>
# <table class="tabular-data-two-column">
# <tr>
# <td>Residential Dwelling</td>
# <td></td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlOcc">
# <tr>
# <td>Occupancy</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Occupancy" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblOccupancy">Single-Family / Owner Occupied</span></td>
# </tr>
# </div>
# <tr>
# <td>Style</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Style" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblStyle">1 Story Frame</span></td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlArchStyle">
# <tr>
# <td>
#                         Architectural Style
#                         </td>
# </tr></div></table></td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="ArchStyle" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblArchStyle">N/A</span>
# </td>
# </tr>
# </table></div>
# <tr>
# <td>Year Built</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="YearBuilt" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblYearBuilt">2017</span></td>
# </tr>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblConditionDescr">Condition</span></td>
# <td>
# <span editkey="Condition" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblCondition">Normal</span></td>
# </tr>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblGradeDescr">Grade</span>
# </td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Grade" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblGrade">N/A</span></td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlFinish">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblRoofDescr">Roof</span></td>
# <td>
# <span editkey="RoofType" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblRoof">Metal / Gable</span></td>
# </tr>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblFlooringDescr">Flooring</span></td>
# <td>
# <span editkey="FloorCoverings" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblFlooring">Carpet / Tile / Hardwood</span></td>
# </tr>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblFoundationDescr">Foundation</span></td>
# <td>
# <span editkey="Foundation" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblFoundation">Concrete</span></td>
# </tr>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblExteriorMaterialDescr">Exterior Material</span></td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="ExteriorMaterial" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblExteriorMaterial">Cement Siding</span></td>
# </tr>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblInteriorMaterialDescr">Interior Material</span></td>
# <td>
# <span editkey="InteriorMaterial" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblInteriorMaterial">Drywall</span></td>
# </tr>
# </div>
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblVeneerDescr">Brick or Stone Veneer</span></td>
# <td>
# <span editkey="Veneer" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblVeneer"></span>
# </td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlExtraFloors">
# <tr>
# <td>First Floor (GLA)</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="FirstFloorLivingArea" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblLivingArea">1,599</span> SF</td>
# </tr>
# <tr>
# <td>Second Floor (GLA)</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="SecondFloorLivingArea" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_Label4">0</span> SF</td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlGLA">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblGLADesc">Gross Living Area</span></td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="LivingArea" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblGLA">1,599</span> SF</td>
# </tr>
# </div>
# <tr>
# <td>Attic Type</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Attic" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblAtticType">None;</span>
# <span editgroup="Res Dwelling 1" editkey="AtticArea" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_Label2"></span></td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlRooms">
# <tr>
# <td>Number of Rooms</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="RoomsCount" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblRoomAboveCount">6 above;</span>
# <span editgroup="Res Dwelling 1" editkey="RoomsCount" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblRoomBelowCount">0 below</span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlBedrooms">
# <tr>
# <td>Number of Bedrooms</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="BedroomsCount" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBedroomAboveCount">3 above;</span>
# <span editgroup="Res Dwelling 1" editkey="BedroomsCount" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBedroomBelowCount">0 below</span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlBasementAreaType">
# <tr>
# <td>Basement Area Type</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="BasementType" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBasementAreaType">Full</span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlBsmtArea">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBsmtAreaDesc">Total Basement Area</span></td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="BasementArea" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBsmtArea">1,599</span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlBsmtFinArea">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBsmtFinAreaDesc">Basement Finished Area</span></td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="BasementFinArea" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblBsmtFinArea"></span></td>
# </tr>
# </div>
# <tr>
# <td>Plumbing</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Plumbing" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblPlumbing">1 Full Bath; 1 Shower Stall Bath; </span></td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlAppliance">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblAppliancesDescr">Appliances</span></td>
# <td>
# <span editkey="Appliances" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblAppliances">1 Dishwasher; 1 Microwave; </span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlCentralAir">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblCentralAirDescr">Central Air</span></td>
# <td>
# <span editkey="CentralAir" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblCentralAir">Yes</span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlHeat">
# <tr>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblHeatDescr">Heat</span></td>
# <td>
# <span editkey="HeatType" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblHeat">FHA - Gas</span></td>
# </tr>
# </div>
# <tr>
# <td>Fireplaces</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Fireplaces" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblFireplace"></span></td>
# </tr>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlPorches">
# <tr>
# <td>Porches</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Porches" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblPorches"></span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlDecks">
# <tr>
# <td>Decks</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Decks" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblDecks">Wood Deck-Med (180 SF); Wood Deck-Med (195 SF); Concrete Patio-Low (100 SF); Concrete Patio-Low (21 SF); Asph/Wd Roof OH-Med (216 SF); Asph/Wd Roof OH-Med (260 SF); </span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlAdditions">
# <tr>
# <td>Additions</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Additions" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblAdditions"></span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlGarages">
# <tr>
# <td>Garages</td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="Garages" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblGarages">632 SF - Att Frame (Built 2017); <br/>894 SF - Det Frame (Built 1952); <br/></span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlSFAREA">
# <tr>
# <td>Main Area Square Feet</td>
# <td>
# <span id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblSFAREA">1599</span></td>
# </tr>
# </div>
# <div id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_pnlGarageObso">
# <tr class="editorHiddenForNormalUsers">
# <td style="width: 186px" valign="top">
# <strong>Garage Obso.</strong></td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="GarageObs" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblGarageObso"></span>
# </td>
# </tr>
# </div>
# <tr class="editorHiddenForNormalUsers">
# <td style="width: 186px" valign="top">
# <strong>Functional Obso. %</strong>
# </td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="FuncObs" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblFunObs">0</span>
# </td>
# </tr>
# <tr class="editorHiddenForNormalUsers">
# <td style="width: 186px" valign="top">
# <strong>Economic Obso. %</strong>
# </td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="EconObs" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_Label5">0</span>
# </td>
# </tr>
# <tr class="editorHiddenForNormalUsers">
# <td style="width: 186px" valign="top">
# <strong>Other Obso. %</strong>
# </td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="OtherObs" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_Label6">0</span>
# </td>
# </tr>
# <tr class="editorHiddenForNormalUsers">
# <td style="width: 186px" valign="top">
# <strong>Obsolescence Reasons</strong>
# </td>
# <td>
# <span editgroup="Res Dwelling 1" editkey="ObsReason" id="ctlBodyPane_ctl05_ctl01_lstResidential_ctl00_lblObsReasons"></span>
# </td>
# </tr>
# </section></main></div></div></div></form></body></html>
#
#
#
#
#
# <section id="ctlBodyPane_ctl07_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl07_divHeader" moduleid="3238">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=451406742&amp;KeyValue=0201100105" id="ctlBodyPane_ctl07_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl07_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl07_lblName" role="heading">Agricultural Buildings</div>
# </a>
# </header>
# <div class="module-content">
# <div>
# <table cellspacing="0" class="tabular-data footable toggle-arrow" data-sort="false" ftmid="3238" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural">
# <thead>
# <tr>
# <th align="left" data-toggle="true" scope="col">Plot #</th><th align="left" scope="col">Type</th><th align="left" scope="col">Description</th><th align="right" data-hide="footable-small" scope="col">Width</th><th align="right" data-hide="footable-small" scope="col">Length</th><th align="right" data-hide="footable-small" scope="col">Year Built</th><th align="right" data-hide="footable-small,footable-medium" scope="col">Appraised Value</th>
# </tr>
# </thead><tbody>
# <tr>
# <th align="left" scope="row">
# <span editgroup="Ag Plot Number 1" editkey="PlotNumber" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblPlotNumber">1</span>
# </th><td align="left">
# <span editgroup="Ag Plot Number 1" editkey="AgDescr" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblAgDescr">Machine or Utility Building</span>
# </td><td align="left">
# <span editgroup="Ag Plot Number 1" editkey="BldgDescr" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblBldgDescr">MACH SHED</span>
# </td><td align="right">
# <span dataformatstring="{0:N0}" editgroup="Ag Plot Number 1" editkey="BldgWidth" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblBldgWidth">34</span>
# </td><td align="right">
# <span dataformatstring="{0:N0}" editgroup="Ag Plot Number 1" editkey="BldgLength" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblBldgLength">35</span>
# </td><td align="right">
# <span editgroup="Ag Plot Number 1" editkey="YearBuilt" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblYearBuilt">1968</span>
# </td><td align="right">
# <span dataformatstring="{0:c0}" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl02_lblAppraisedValue">$0</span>
# </td>
# </tr><tr>
# <th align="left" scope="row">
# <span editgroup="Ag Plot Number 2" editkey="PlotNumber" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblPlotNumber">2</span>
# </th><td align="left">
# <span editgroup="Ag Plot Number 2" editkey="AgDescr" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblAgDescr">Swine Finish and Farrow (Old Style)</span>
# </td><td align="left">
# <span editgroup="Ag Plot Number 2" editkey="BldgDescr" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblBldgDescr">HOG HOUSE</span>
# </td><td align="right">
# <span dataformatstring="{0:N0}" editgroup="Ag Plot Number 2" editkey="BldgWidth" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblBldgWidth">20</span>
# </td><td align="right">
# <span dataformatstring="{0:N0}" editgroup="Ag Plot Number 2" editkey="BldgLength" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblBldgLength">42</span>
# </td><td align="right">
# <span editgroup="Ag Plot Number 2" editkey="YearBuilt" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblYearBuilt">1940</span>
# </td><td align="right">
# <span dataformatstring="{0:c0}" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl03_lblAppraisedValue">$0</span>
# </td>
# </tr><tr>
# <th align="left" scope="row">
# <span editgroup="Ag Plot Number 3" editkey="PlotNumber" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblPlotNumber">3</span>
# </th><td align="left">
# <span editgroup="Ag Plot Number 3" editkey="AgDescr" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblAgDescr">Shed - Loafing</span>
# </td><td align="left">
# <span editgroup="Ag Plot Number 3" editkey="BldgDescr" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblBldgDescr">CATTLE SHED</span>
# </td><td align="right">
# <span dataformatstring="{0:N0}" editgroup="Ag Plot Number 3" editkey="BldgWidth" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblBldgWidth">24</span>
# </td><td align="right">
# <span dataformatstring="{0:N0}" editgroup="Ag Plot Number 3" editkey="BldgLength" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblBldgLength">40</span>
# </td><td align="right">
# <span editgroup="Ag Plot Number 3" editkey="YearBuilt" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblYearBuilt">1976</span>
# </td><td align="right">
# <span dataformatstring="{0:c0}" id="ctlBodyPane_ctl07_ctl01_gvwAgricultural_ctl04_lblAppraisedValue">$900</span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="editorHiddenForNormalUsers" id="ctlBodyPane_ctl07_ctl01_pnlEditorNewData">
# <strong>Add an improvement:</strong>
# <table border="0" cellpadding="1" cellspacing="1" id="Table3" style="border-width: thin; border-style: solid;" width="100%">
# <tr>
# <td>
# <strong>Plot #</strong>
# </td>
# <td>
# <strong>Type</strong>
# </td>
# <td>
# <strong>Description</strong>
# </td>
# <td>
# <strong>Width</strong>
# </td>
# <td>
# <strong>Length</strong>
# </td>
# <td>
# <strong>Year Built</strong>
# </td>
# <td>
# <strong>Building Count</strong>
# </td>
# </tr>
# <tr style="vertical-align: text-top">
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="PlotNumber" id="ctlBodyPane_ctl07_ctl01_newPlotNumber1"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="AgDescr" id="ctlBodyPane_ctl07_ctl01_newAgDescr1"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="BldgDescr" id="ctlBodyPane_ctl07_ctl01_newBldgDescr1"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="BldgWidth" id="ctlBodyPane_ctl07_ctl01_newBldgWidth1"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="BldgLength" id="ctlBodyPane_ctl07_ctl01_newBldgLength1"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="YearBuilt" id="ctlBodyPane_ctl07_ctl01_newYearBuilt1"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding1" editkey="BldgCount" id="ctlBodyPane_ctl07_ctl01_newBldgCount1"></span>
# </td>
# </tr>
# <tr style="vertical-align: text-top">
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="PlotNumber" id="ctlBodyPane_ctl07_ctl01_newPlotNumber2"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="AgDescr" id="ctlBodyPane_ctl07_ctl01_newAgDescr2"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="BldgDescr" id="ctlBodyPane_ctl07_ctl01_newBldgDescr2"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="BldgWidth" id="ctlBodyPane_ctl07_ctl01_newBldgWidth2"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="BldgLength" id="ctlBodyPane_ctl07_ctl01_newBldgLength2"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="YearBuilt" id="ctlBodyPane_ctl07_ctl01_newYearBuilt2"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding2" editkey="BldgCount" id="ctlBodyPane_ctl07_ctl01_newBldgCount2"></span>
# </td>
# </tr>
# <tr style="vertical-align: text-top">
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="PlotNumber" id="ctlBodyPane_ctl07_ctl01_newPlotNumber3"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="AgDescr" id="ctlBodyPane_ctl07_ctl01_newAgDescr3"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="BldgDescr" id="ctlBodyPane_ctl07_ctl01_newBldgDescr3"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="BldgWidth" id="ctlBodyPane_ctl07_ctl01_newBldgWidth3"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="BldgLength" id="ctlBodyPane_ctl07_ctl01_newBldgLength3"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="YearBuilt" id="ctlBodyPane_ctl07_ctl01_newYearBuilt3"></span>
# </td>
# <td style="vertical-align: text-top">
# <span editgroup="NewAgBuilding3" editkey="BldgCount" id="ctlBodyPane_ctl07_ctl01_newBldgCount3"></span>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </section>
# <section id="ctlBodyPane_ctl09_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl09_divHeader" moduleid="3240">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=451406742&amp;KeyValue=0201100105" id="ctlBodyPane_ctl09_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl09_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl09_lblName" role="heading">Sales</div>
# </a>
# </header>
# <div class="module-content">
# <div>
# <table cellspacing="0" class="tabular-data footable toggle-arrow" data-sort="false" ftmid="3240" id="ctlBodyPane_ctl09_ctl01_gvwSales">
# <thead>
# <tr>
# <th align="left" data-toggle="true" scope="col">Date</th><th align="left" data-hide="footable-small" scope="col">Seller</th><th align="left" data-hide="footable-small" scope="col">Buyer</th><th align="left" data-hide="footable-small,footable-medium" scope="col">Recording</th><th align="left" data-hide="footable-small,footable-medium" scope="col">Sale Condition - NUTC</th><th align="left" data-hide="footable-small,footable-medium" scope="col">Type</th><th align="center" data-hide="footable-small,footable-medium" scope="col">Multi <br/>Parcel</th><th align="right" scope="col">Amount</th>
# </tr>
# </thead><tbody>
# <tr>
# <th scope="row">6/30/2004</th><td>WATSON, CARL W</td><td>RISDAL, AARON &amp; DAWN</td><td>04-08964</td><td>Normal</td><td>Deed</td><td align="center"> </td><td align="right">$134,900.00</td>
# </tr>
# </tbody>
# </table>
# </div>
# <br>
# <div style="text-align: center">
# </div>
# </br></div>
# </section>
# <section id="ctlBodyPane_ctl18_mSection">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl18_divHeader" moduleid="8811">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=1221934670&amp;KeyValue=0201100105" id="ctlBodyPane_ctl18_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl18_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl18_lblName" role="heading">Valuation (Story County)</div>
# </a>
# </header>
# <div class="module-content">
# <table cellspacing="0" class="tabular-data footable toggle-arrow" data-sort="false" ftmid="8811" id="ctlBodyPane_ctl18_ctl01_grdValuation" rowheaderindex="1" width="100%">
# <thead>
# <tr>
# <td data-toggle="true" scope="col" width="16"> </td><td scope="row"> </td><th class="value-column" scope="col">2020</th><th class="value-column" scope="col">2019</th><th class="value-column" data-hide="footable-small" scope="col">2018</th><th class="value-column" data-hide="footable-small" scope="col">2017</th><th class="value-column" data-hide="footable-small,footable-medium" scope="col">2016</th><th class="value-column" data-hide="footable-small,footable-medium" scope="col">2015</th>
# </tr>
# </thead><tbody>
# <tr>
# ...
# <a class="rsImg" data-index="15" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/15?sv=2015-07-08&amp;sr=b&amp;sig=gdB7xf84BdLH4VPt3g4oU5TZIRBdARd57XRLTToXNdQ%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/15?sv=2015-07-08&amp;sr=b&amp;sig=NPWzRqyRNCH99fkAWINPNfj0w9iB92b3ds444o5UWo0%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>REAR VIEW 10/18/2018</a>
# <a class="rsImg" data-index="16" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/16?sv=2015-07-08&amp;sr=b&amp;sig=JMtntBmVdmt1sdB7dOvSivCoEQecd8%2Bg07fnglBN7Y4%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/16?sv=2015-07-08&amp;sr=b&amp;sig=jed7wHzkZt3RPd0PWIZosVeJS9AgNV7YslUQ4X0w1YI%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>REAR VIEW 10/18/2018</a>
# <a class="rsImg" data-index="17" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/17?sv=2015-07-08&amp;sr=b&amp;sig=DWsir46XNehDZO%2FNKVBSo3tVJwY%2Fi0u699kuYePIGx8%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/17?sv=2015-07-08&amp;sr=b&amp;sig=mW92nJWcqowfcepAfj%2BfE80Dq3jCBtMbkTLdjAmsRIE%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>DETACHED GARAGE 10/18/2018</a>
# <a class="rsImg" data-index="18" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/18?sv=2015-07-08&amp;sr=b&amp;sig=Erz6AerSGTTvEZXpoMnTsMDvYWH%2FSiOle8z4ltVnuRY%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/18?sv=2015-07-08&amp;sr=b&amp;sig=fWcLcGVoj2eS5TAouu0DGKkry1%2BGPGpPBHRV9i42MB4%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>STEEL UTILITY BUILDING 10/18/2018</a>
# <a class="rsImg" data-index="19" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/19?sv=2015-07-08&amp;sr=b&amp;sig=609XBGHtXtKiPvZV31JocElruPW%2BMQftaTriKT0qeNU%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/19?sv=2015-07-08&amp;sr=b&amp;sig=sLrdW4ED9oWH0g11gOj34rDew%2BCbegrOGAWYkG3zec8%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>SWINE FINISHING AND CATTLE SHED 10/18/2018</a>
# <a class="rsImg" data-index="20" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/20?sv=2015-07-08&amp;sr=b&amp;sig=NVDmMtxCpEV5kpK1odNbUdOqPub5yR6Ig%2FZz6k9xkcU%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/20?sv=2015-07-08&amp;sr=b&amp;sig=0NJ66g9WNyHvcoPJthN7K56p%2BpaQ4AKaGcjVREm3mA0%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>FRONT VIEW 12/06/2017</a>
# <a class="rsImg" data-index="21" data-rsbigimg="https://venturi.blob.core.windows.net/fd-2409/0/0201100105/21?sv=2015-07-08&amp;sr=b&amp;sig=cyBxzBZqN3veuxdpZuxTZJs24XCQwZH7arIu5U%2Bkx2I%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" href="https://venturi.blob.core.windows.net/fd-2409/1/0201100105/21?sv=2015-07-08&amp;sr=b&amp;sig=mr%2Bxaol3rvc7osw3bcJ4hpgo9Z3IzZQKmOtoZVcgRuA%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline" onerror="Beacon.LazyLoader.swapCarouselImageOnError"><span class="sr-only">Property Photo </span>REAR VIEW 12/06/2017</a>
# </div>
# </div>
# </section>
# <section id="ctlBodyPane_ctl32_mSection" layout="IMAGE">
# <header class="module-header" defaultvisibility="True" id="ctlBodyPane_ctl32_divHeader" moduleid="3242">
# <a aria-expanded="true" class="toggle-collapse" href="/Application.aspx?AppID=165&amp;LayerID=2145&amp;PageTypeID=4&amp;PageID=1108&amp;Q=144647380&amp;KeyValue=0201100105" id="ctlBodyPane_ctl32_btnHeaderToggle">
# <span class="toggle-collapse-icon icon icon-minus-squared-alt" id="ctlBodyPane_ctl32_btnToggleVis"></span>
# <div aria-level="2" class="title" id="ctlBodyPane_ctl32_lblName" role="heading">Sketches</div>
# </a>
# </header>
# <div class="module-content">
# <div class="clearfix" id="sketchgrid">
# <div class="sketch-thumbnail" title="Click to enlarge sketch">
# <img alt="Building Sketch 1" class="rsImg" data-index="0" src="https://venturi.blob.core.windows.net/fd-2410/0201100105/0?sv=2015-07-08&amp;sr=b&amp;sig=mC0XsFh0XXuMAfXt1%2FpxZyCoLHjsaNOCwchwema4Ofs%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline"/>
# <div class="sketch-thumbnail-caption"></div>
# <div class="sketch-thumbnail-caption-print"></div>
# </div>
# <div class="sketch-thumbnail" title="Click to enlarge sketch">
# <img alt="Building Sketch 2" class="rsImg" data-index="1" src="https://venturi.blob.core.windows.net/fd-2410/0201100105/1?sv=2015-07-08&amp;sr=b&amp;sig=ixDW26wVIXYdbpYose0J5M%2FkEps6bitgyvgzAgmOYoU%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline"/>
# <div class="sketch-thumbnail-caption"></div>
# <div class="sketch-thumbnail-caption-print"></div>
# </div>
# </div>
# <div class="hide" id="sketchlist">
# <a class="rsImg" data-index="0" href="https://venturi.blob.core.windows.net/fd-2410/0201100105/0?sv=2015-07-08&amp;sr=b&amp;sig=mC0XsFh0XXuMAfXt1%2FpxZyCoLHjsaNOCwchwema4Ofs%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline"><span class="sr-only">Building Sketch </span></a>
# <a class="rsImg" data-index="1" href="https://venturi.blob.core.windows.net/fd-2410/0201100105/1?sv=2015-07-08&amp;sr=b&amp;sig=ixDW26wVIXYdbpYose0J5M%2FkEps6bitgyvgzAgmOYoU%3D&amp;se=2020-07-16T07%3A00%3A00Z&amp;sp=r&amp;rscd=inline"><span class="sr-only">Building Sketch </span></a>
# </div>
# <center><b><font color="red">Click sketch thumbnail to enlarge.</font></b></center>
# </div>
# </section>
# <div class="nodata-modulelist" id="ctlBodyPane_noDataList_pnlNoDataForModules">
# <strong>No data available for the following modules:</strong>
#     Property Record Card (Ames), Commercial/Industrial Buildings, Yard Extras, Site Description (Ames), Land (Ames), Farm Land Computations (Ames), Residential (Ames), Commercial (Ames), Improvements (Ames), Transfers (Ames), Res Sales (Ames), Valuation (Ames), Taxation (Ames), Tax Sale Certificates, Special Assessments.
#
# </div>
#
#
# <div class="col-md-2 page-right-pane">
# <div id="rightPaneAffix">
# <section role="complementary">
# <header class="module-header">
# <a aria-expanded="false" class="toggle-collapse" href="#">
# <span class="toggle-collapse-icon icon icon-plus-squared-alt" id="InfoPane2_btnToggleVis"></span>
# <div aria-level="2" class="title" role="heading">Contact Information</div>
# </a>
# </header>
# <div class="right-pane-block info-pane collapse-content">
# <h2 class="right-pane-header" id="InfoPane2_divInfoHeader">
#             Information
#         </h2>
# <div>
# <img alt="Story County Administration Building" class="info-pane-photo" id="InfoPane2_imgPhoto" src="/FileData/BeaconClientData/StoryCountyIA/storycourthouse.jpg"/>
# </div>
# <div class="info-pane-photo-caption">
# <div class="line1">
# <span id="InfoPane2_txtLine1">Story County, IA </span>
# </div>
# <div class="line2">
# <span id="InfoPane2_txtLine2">900 6th St</span>
# </div>
# <div class="line3">
# <span id="InfoPane2_txtLine3">Nevada, IA 50201</span>
# </div>
# <div class="line4">
# <span id="InfoPane2_txtLine4"></span>
# </div>
# <div class="line5">
# <span id="InfoPane2_txtLine5"></span>
# </div>
# <div class="website">
# <a href="http://www.storycountyiowa.gov/assessor" id="InfoPane2_lnkWebsite" target="_blank">Story County Assessor <span class="sr-only">opens in a new tab</span></a>
# </div>
# </div>
# <div class="info-pane-item">
# <div class="photo">
# <img alt="Ames City Hall" id="InfoPane2_rptInfo2_ctl00_imgPhoto" src="/FileData/BeaconClientData/StoryCountyIA/AmesCombo_640x788.jpg"/>
# </div>
# <div class="title">
# <a href="http://www.cityofames.org/index.aspx?page=99" id="InfoPane2_rptInfo2_ctl00_lnkTitle" target="_blank" title="Opens in a new tab">City of Ames Assessor</a>
# </div>
# <div class="name">
# <span id="InfoPane2_rptInfo2_ctl00_lnkNameTxt">515 Clark Ave, Ames, IA 50010</span>
# </div>
# <div class="phone">
# <span id="InfoPane2_rptInfo2_ctl00_txtPhone">CityAssessorInfo@cityofames.org</span>
# </div>
# </div>
# <div class="info-pane-item">
# <div class="photo">
# </div>
# <div class="title">
# <a href="http://www.cityofames.org/index.aspx?page=492" id="InfoPane2_rptInfo2_ctl01_lnkTitle" target="_blank" title="Opens in a new tab">Click for additional reports / info</a>
# </div>
# <div class="name">
# <span id="InfoPane2_rptInfo2_ctl01_lnkNameTxt"></span>
# </div>
# <div class="phone">
# <span id="InfoPane2_rptInfo2_ctl01_txtPhone">____________________________________</span>
# </div>
# </div>
# <div class="info-pane-item">
# <div class="photo">
# <img id="InfoPane2_rptInfo2_ctl02_imgPhoto" src="/FileData/BeaconClientData/StoryCountyIA/StoryCountyIA_Maps.jpg"/>
# </div>
# <div class="title">
# <a href="http://www.storycountyiowa.gov/gis" id="InfoPane2_rptInfo2_ctl02_lnkTitle" target="_blank" title="Opens in a new tab">GIS Webpage</a>
# </div>
# <div class="name">
# <span id="InfoPane2_rptInfo2_ctl02_lnkNameTxt"></span>
# </div>
# <div class="phone">
# <span id="InfoPane2_rptInfo2_ctl02_txtPhone"></span>
# </div>
# </div>
# <div class="info-pane-item">
# <div class="photo">
# </div>
# <div class="title">
# <span id="InfoPane2_rptInfo2_ctl03_lnkTitleTxt">Story County GIS Coordinator</span>
# </div>
# <div class="name">
# <a href="mailto:mboeck@storycounty.com" id="InfoPane2_rptInfo2_ctl03_lnkName" target="_blank" title="Opens in a new tab">Matt Boeck </a>
# </div>
# <div class="phone">
# <span id="InfoPane2_rptInfo2_ctl03_txtPhone">(515) 382-7327</span>
# </div>
# </div>
# <div class="info-pane-item">
# <div class="photo">
# </div>
# <div class="title">
# <span id="InfoPane2_rptInfo2_ctl04_lnkTitleTxt">City of Ames GIS Coordinator</span>
# </div>
# <div class="name">
# <a href="mailto:mailto:bmcconville@CityOfAmes.org" id="InfoPane2_rptInfo2_ctl04_lnkName" target="_blank" title="Opens in a new tab">Ben McConville</a>
# </div>
# <div class="phone">
# <span id="InfoPane2_rptInfo2_ctl04_txtPhone">(515) 239-5162</span>
# </div>
# </div>
# <div class="info-pane-item">
# <div class="photo">
# </div>
# <div class="title">
# <span id="InfoPane2_rptInfo2_ctl05_lnkTitleTxt"></span>
# </div>
# <div class="name">
# <span id="InfoPane2_rptInfo2_ctl05_lnkNameTxt"></span>
# </div>
# <div class="phone">
# <span id="InfoPane2_rptInfo2_ctl05_txtPhone"></span>
# </div>
# </div>
# </div>
# </section>
# <section>
# <header class="module-header">
# <a aria-expanded="false" class="toggle-collapse" href="#">
# <span class="toggle-collapse-icon icon icon-plus-squared-alt" id="ctlAnnouncements_btnToggleVis"></span>
# <div aria-level="2" class="title" role="heading">Announcements</div>
# </a>
# </header>
# <div class="announcement-content right-pane-block NoPrint collapse-content">
# <h2 class="right-pane-header">Announcements</h2>
# <div class="right-pane-content">
# <ul class="list-unstyled">
# <li>
# <span id="ctlAnnouncements_rpAnnouncements_ctl00_lblSubject"><a href="http://schneidercorp.com/register/qpublic-net-demo-access/">How to use the qPublic.net site – view Demo Videos</a></span>
# </li>
# <li>
# <span id="ctlAnnouncements_rpAnnouncements_ctl01_lblSubject"><a href="http://guidepost.schneidercorp.com">Search across multiple counties with Guidepost!</a></span>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </div>
#
#
# <div class="container-fluid footer-container" role="contentinfo">
# <div class="row">
# <div class="container">
# <div class="row">
# <div class="col-sm-10 footer-disclaimer-text">
# <div>
# <span id="ctlFooter_ctlDisclaimer_txtShortDisclaimer">The information in this web site represents current data from a working file which is updated continuously. Information is believed reliable, but its accuracy cannot be guaranteed.</span>
# </div>
# <div class="NoPrint" id="ctlFooter_ctlDisclaimer_divDisclaimerButton">
# <a href="#" id="btnViewLongDisclaimer" title="">View full version <span class="sr-only"> Opens in dialog</span></a>
# </div>
# <a href="https://www.schneidergis.com/privacypolicy" id="ctlFooter_ctlDisclaimer_lnkUserPrivacyPolicy" target="_blank" title="Opens in a new tab">User Privacy Policy</a>
# <br>
# <a href="https://www.schneidergis.com/gdprprivacynotice" id="ctlFooter_ctlDisclaimer_lnkGDPRPrivacyNotice" target="_blank" title="Opens in a new tab">GDPR Privacy Notice</a>
# <script>
#     $('#btnViewLongDisclaimer').click(function (e) {
#
#         $.get("/services/fulldisclaimer.aspx?appid=" + mapConfig.AppId).then(function (d) {
#             Beacon.Dialogs.showWithHtml(e.target, "Disclaimer", d, false, "Close");
#         });
#
#         e.preventDefault();
#         return false;
#     });
# </script>
# <div class="footer-sv-update">
# <a aria-label="Opens dialog" href="/LastUpdated.aspx?BaseDoc=StoryCountyIA&amp;AppID=165" id="hlkLastUpdated" title="View Data update status"></a>
# <script>
#
#     $("#hlkLastUpdated").click(function (e) {
#
#         $.get('/LastUpdated.aspx?BaseDoc=StoryCountyIA&AppID=165').then(function (d) {
#             Beacon.Dialogs.showWithHtml(e.target, "Data update status", d, false, "Close");
#         });
#         e.preventDefault();
#     });
#
#     var sethlkLastUpdatedText = function (utcDTString) { // This is called from a registered script block from server code...AL
#         if (utcDTString) $("#hlkLastUpdated").text("Last Data Upload: " + Beacon.Utils.utcDTStringToLocalDTString(utcDTString));
#     };
#
# </script>
# <div class="pull-right">
# <a aria-label="open version '2.3.69' in dialog" href="#" id="btnViewReleaseHistory">Version 2.3.69</a>
# </div>
# </div>
# </br></div>
# <div class="col-sm-2">
# <div class="footer-credits" id="ctlFooter_footerBrandingBlock">
# <div>Developed by</div>
# <div class="icon-sg-logoPrint">
# <a href="http://schneidergis.com" target="_blank"><img alt="Schneider Geospatial Logo - Opens in a new tab" class="icon-sg-logo" src="./Images/Logos/sg-color.png"/></a>
# </div>
# <div class="icon-sg-logoScreen">
# <a href="http://schneidergis.com" target="_blank"><img alt="Schneider Geospatial Logo  - Opens in a new tab" class="icon-sg-logo" src="./Images/Logos/SG%20Footer.png"/></a>
# </div>
# </div>
# <div class="social NoPrint" id="ctlFooter_socialMediaLinkBlock">
# <a href="https://www.facebook.com/schneidergeospatial" target="_blank"><span class="icon icon-facebook-squared"></span><span class="sr-only">Facebook - opens in a new tab</span></a>
# <a href="https://www.twitter.com/gisschneider" target="_blank"><span class="icon icon-twitter-squared"></span><span class="sr-only">Twitter - opens in a new tab</span></a>
# <a href="https://www.linkedin.com/company/schneider-geospatial/" target="_blank"><img alt="LinkedIn Logo" class="icon" src="../../Images/Logos/IN%20Footer.png" style="margin-top: -13px;"/><span class="sr-only">LinkedIn - opens in a new tab</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#     $('#btnViewReleaseHistory').click(function (e) {
#
#         $.get("/Release?AppId=165").then(function (d) {
#             Beacon.Dialogs.showWithHtml(e.target, "Release History", d, false, "Close");
#         });
#
#         e.preventDefault();
#         return false;
#     });
# </script>
# <script type="text/javascript">
# //<![CDATA[
# $(document).ready(sethlkLastUpdatedText('2020-07-15T01:21:57.1765854Z'));//]]>
# </script>
#
# <!-- Server: TSC-GIS-BEACON6, App: BeaconBeta, Version: 2.3.69 60d45d90 -->

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-dc9ad60ea6b5> in <module>
# ----> 1 table[18]
#
# IndexError: list index out of range
